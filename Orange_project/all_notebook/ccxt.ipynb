# %%
import ccxt.pro as ccxtpro
import asyncio
import nest_asyncio
import pytz
from datetime import datetime, timedelta
import pandas as pd
from ccxt_lab import whale_1, testnet_api_key, testnet_api_secret

# Use nest_asyncio to allow async/await code to run in Jupyter Notebook
nest_asyncio.apply()

async def fetch_ohlcv_dataframe(exchange, symbol):
    try:
        current_time_utc = datetime.utcnow() - timedelta(hours=1)
        start_time_str = current_time_utc.strftime('%Y-%m-%dT%H:%M:%SZ')
        start_timestamp = exchange.parse8601(start_time_str)

        ohlcv = await exchange.fetch_ohlcv(symbol, timeframe='1m', since=start_timestamp, limit=None)

        df = pd.DataFrame(ohlcv, columns=['Timestamp', 'Open', 'High', 'Low', 'Close', 'Volume'])
        df['Timestamp'] = pd.to_datetime(df['Timestamp'], unit='ms')
        df['Timestamp'] = df['Timestamp'] + timedelta(hours=8)
        df['Last5VolumeSum'] = df['Volume'].rolling(window=6, min_periods=1).sum() - df['Volume']

        return df

    except Exception as e:
        print(f"An error occurred: {e}")
        return None

async def watch_ohlcv_and_print(exchange, symbol, whale):
    utc_plus_8 = pytz.timezone('Asia/Shanghai')
    previous_timestamp = None
    entry_time_list = []

    try:
        while True:
            ohlcv = await exchange.watch_ohlcv(symbol, timeframe='1m')
            timestamp_utc = datetime.fromtimestamp(ohlcv[-1][0] / 1000, tz=pytz.utc)
            timestamp_utc8 = timestamp_utc.astimezone(utc_plus_8)
            current_timestamp_str = timestamp_utc8.strftime('%Y-%m-%d %H:%M:%S')
            current_volume = ohlcv[-1][5]

            if current_timestamp_str != previous_timestamp:
                print(f"New timestamp: {current_timestamp_str}")
                df = await fetch_ohlcv_dataframe(exchange, symbol)
                previous_timestamp = current_timestamp_str

            print(f"Current volume: {ohlcv[-1][5]}, Test value: {df['Volume'].iloc[-2]}")

            if df is not None and current_volume > df['Volume'].iloc[-2]:
                if not whale.is_position_open() and current_timestamp_str not in entry_time_list:
                    try:
                        direction = 'buy' if ohlcv[-1][4] > ohlcv[-1][1] else 'sell'
                        place_order = whale.place_first_market_order(direction)
                        print(f"Place order: {place_order}")
                        entry_time_list.append(current_timestamp_str)
                        whale.place_second_take_profit_and_stop_loss_orders()

                    except Exception as e:
                        print(f"An error occurred: {e}")

            print(f"Time: {current_timestamp_str}, Open: {ohlcv[-1][1]}, High: {ohlcv[-1][2]}, Low: {ohlcv[-1][3]}, Close: {ohlcv[-1][4]}, Volume: {ohlcv[-1][5]}, Last 5 volume sum: {df['Last5VolumeSum'].iloc[-1]:.2f}")

    except KeyboardInterrupt:
        pass
    finally:
        await exchange.close()

async def constantly_watch_position_and_orders(exchange, symbol, whale):
    prev_position_exists = False

    try:
        while True:
            positions = await exchange.fetch_positions([symbol])
            current_position_Amt_abs = abs(float(positions[0]['info']['positionAmt']))
            position_exists = (current_position_Amt_abs > 0 or current_position_Amt_abs < 0)

            if position_exists and not prev_position_exists:
                print("Position exists from None")
            
            if not position_exists and prev_position_exists:
                print("No position anymore")
                whale.close_position_and_orders()

            prev_position_exists = position_exists

    except KeyboardInterrupt:
        pass
    finally:
        whale_1.close_position_and_orders()
        await exchange.close()

async def main():
    trading_symbol = 'ETH/USDT'

    exchange = ccxtpro.binance({
        'options': {
            'defaultType': 'future',
            'newUpdates': True
        },
        'api_key': testnet_api_key,
        'secret': testnet_api_secret
    })
    
    exchange.set_sandbox_mode(True)
    tasks = [
        watch_ohlcv_and_print(exchange, trading_symbol, whale_1),
        constantly_watch_position_and_orders(exchange, trading_symbol, whale_1)
    ]
    await asyncio.gather(*tasks)

api_key = testnet_api_key
api_secret = testnet_api_secret

asyncio.run(main())
# Out:
# New timestamp: 2023-10-12 18:37:00
# Current volume: 126.819, Test value: 107.065
# Place order: {'info': {'orderId': '1184685773', 'symbol': 'ETHUSDT', 'status': 'FILLED', 'clientOrderId': 'x-xcKtGhcu74528c3533443b3c27fc41', 'price': '0.00', 'avgPrice': '1547.37790', 'origQty': '6.465', 'executedQty': '6.465', 'cumQty': '6.465', 'cumQuote': '10003.79813', 'timeInForce': 'GTC', 'type': 'MARKET', 'reduceOnly': False, 'closePosition': False, 'side': 'BUY', 'positionSide': 'BOTH', 'stopPrice': '0.00', 'workingType': 'CONTRACT_PRICE', 'priceProtect': False, 'origType': 'MARKET', 'priceMatch': 'NONE', 'selfTradePreventionMode': 'NONE', 'goodTillDate': '0', 'updateTime': '1697107043989'}, 'id': '1184685773', 'clientOrderId': 'x-xcKtGhcu74528c3533443b3c27fc41', 'timestamp': 1697107043989, 'datetime': '2023-10-12T10:37:23.989Z', 'lastTradeTimestamp': 1697107043989, 'lastUpdateTimestamp': 1697107043989, 'symbol': 'ETH/USDT:USDT', 'type': 'market', 'timeInForce': 'GTC', 'postOnly': False, 'reduceOnly': False, 'side': 'buy', 'price': 1547.3779, 'triggerPrice': None, 'amount': 6.465, 'cost': 10003.79813, 'average': 1547.3779, 'filled': 6.465, 'remaining': 0.0, 'status': 'closed', 'fee': {'currency': None, 'cost': None, 'rate': None}, 'trades': [], 'fees': [{'currency': None, 'cost': None, 'rate': None}], 'stopPrice': None, 'takeProfitPrice': None, 'stopLossPrice': None}
# Time: 2023-10-12 18:37:00, Open: 1546.94, High: 1547.32, Low: 1545.88, Close: 1547.32, Volume: 126.819, Last 5 volume sum: 457.36
# Current volume: 129.413, Test value: 107.065
# Time: 2023-10-12 18:37:00, Open: 1546.94, High: 1547.33, Low: 1545.88, Close: 1547.33, Volume: 129.413, Last 5 volume sum: 457.36
# Current volume: 135.273, Test value: 107.065
# Time: 2023-10-12 18:37:00, Open: 1546.94, High: 1547.41, Low: 1545.88, Close: 1547.41, Volume: 135.273, Last 5 volume sum: 457.36
# Position exists from None
# Current volume: 138.233, Test value: 107.065
# Time: 2023-10-12 18:37:00, Open: 1546.94, High: 1547.42, Low: 1545.88, Close: 1547.42, Volume: 138.233, Last 5 volume sum: 457.36
# Current volume: 138.252, Test value: 107.065
# Time: 2023-10-12 18:37:00, Open: 1546.94, High: 1547.42, Low: 1545.88, Close: 1547.42, Volume: 138.252, Last 5 volume sum: 457.36
# Current volume: 138.908, Test value: 107.065
# Time: 2023-10-12 18:37:00, Open: 1546.94, High: 1547.45, Low: 1545.88, Close: 1547.45, Volume: 138.908, Last 5 volume sum: 457.36
# Current volume: 140.523, Test value: 107.065
# Time: 2023-10-12 18:37:00, Open: 1546.94, High: 1547.45, Low: 1545.88, Close: 1547.45, Volume: 140.523, Last 5 volume sum: 457.36
# Current volume: 140.575, Test value: 107.065
# Time: 2023-10-12 18:37:00, Open: 1546.94, High: 1547.45, Low: 1545.88, Close: 1547.45, Volume: 140.575, Last 5 volume sum: 457.36
# Current volume: 141.873, Test value: 107.065
# Time: 2023-10-12 18:37:00, Open: 1546.94, High: 1547.46, Low: 1545.88, Close: 1547.46, Volume: 141.873, Last 5 volume sum: 457.36
# Current volume: 141.878, Test value: 107.065
# Time: 2023-10-12 18:37:00, Open: 1546.94, High: 1547.46, Low: 1545.88, Close: 1547.45, Volume: 141.878, Last 5 volume sum: 457.36
# Current volume: 143.174, Test value: 107.065
# Time: 2023-10-12 18:37:00, Open: 1546.94, High: 1547.56, Low: 1545.88, Close: 1547.56, Volume: 143.174, Last 5 volume sum: 457.36
# Current volume: 146.572, Test value: 107.065
# Time: 2023-10-12 18:37:00, Open: 1546.94, High: 1547.62, Low: 1545.88, Close: 1547.62, Volume: 146.572, Last 5 volume sum: 457.36
# Current volume: 146.577, Test value: 107.065
# Time: 2023-10-12 18:37:00, Open: 1546.94, High: 1547.62, Low: 1545.88, Close: 1547.52, Volume: 146.577, Last 5 volume sum: 457.36
# Current volume: 157.993, Test value: 107.065
# Time: 2023-10-12 18:37:00, Open: 1546.94, High: 1547.62, Low: 1545.88, Close: 1547.46, Volume: 157.993, Last 5 volume sum: 457.36
# Current volume: 158.316, Test value: 107.065
# Time: 2023-10-12 18:37:00, Open: 1546.94, High: 1547.62, Low: 1545.88, Close: 1547.46, Volume: 158.316, Last 5 volume sum: 457.36
# Current volume: 158.962, Test value: 107.065
# Time: 2023-10-12 18:37:00, Open: 1546.94, High: 1547.62, Low: 1545.88, Close: 1547.46, Volume: 158.962, Last 5 volume sum: 457.36
# Current volume: 161.545, Test value: 107.065
# Time: 2023-10-12 18:37:00, Open: 1546.94, High: 1547.62, Low: 1545.88, Close: 1547.39, Volume: 161.545, Last 5 volume sum: 457.36
# Current volume: 164.367, Test value: 107.065
# Time: 2023-10-12 18:37:00, Open: 1546.94, High: 1547.62, Low: 1545.88, Close: 1547.3, Volume: 164.367, Last 5 volume sum: 457.36
# New timestamp: 2023-10-12 18:38:00
# Current volume: 19.877, Test value: 164.367
# Time: 2023-10-12 18:38:00, Open: 1547.39, High: 1547.39, Low: 1547.17, Close: 1547.17, Volume: 19.877, Last 5 volume sum: 553.50
# Current volume: 22.292, Test value: 164.367
# Time: 2023-10-12 18:38:00, Open: 1547.39, High: 1547.39, Low: 1547.14, Close: 1547.14, Volume: 22.292, Last 5 volume sum: 553.50
# Current volume: 30.064, Test value: 164.367
# Time: 2023-10-12 18:38:00, Open: 1547.39, High: 1547.39, Low: 1547.01, Close: 1547.01, Volume: 30.064, Last 5 volume sum: 553.50
# Current volume: 37.049, Test value: 164.367
# Time: 2023-10-12 18:38:00, Open: 1547.39, High: 1547.39, Low: 1547.01, Close: 1547.06, Volume: 37.049, Last 5 volume sum: 553.50
# Current volume: 39.582, Test value: 164.367
# Time: 2023-10-12 18:38:00, Open: 1547.39, High: 1547.39, Low: 1546.91, Close: 1546.91, Volume: 39.582, Last 5 volume sum: 553.50
# Current volume: 50.84, Test value: 164.367
# Time: 2023-10-12 18:38:00, Open: 1547.39, High: 1547.39, Low: 1546.91, Close: 1547.04, Volume: 50.84, Last 5 volume sum: 553.50
# Current volume: 114.418, Test value: 164.367
# Time: 2023-10-12 18:38:00, Open: 1547.39, High: 1547.4, Low: 1546.88, Close: 1546.88, Volume: 114.418, Last 5 volume sum: 553.50
# Current volume: 116.708, Test value: 164.367
# Time: 2023-10-12 18:38:00, Open: 1547.39, High: 1547.4, Low: 1546.68, Close: 1546.68, Volume: 116.708, Last 5 volume sum: 553.50
# No position anymore
# Error in closing position: binance amount of ETH/USDT:USDT must be greater than minimum amount precision of 3
# ---------------------------------------------------------------------------
# NetworkError                              Traceback (most recent call last)
# /allah/freqtrade/json_dict/ccxt.ipynb Cell 1 line 1
#     <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a224c696e6f64655f73696e6761706f7265227d/allah/freqtrade/json_dict/ccxt.ipynb#W0sdnNjb2RlLXJlbW90ZQ%3D%3D?line=112'>113</a> api_key = testnet_api_key
#     <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a224c696e6f64655f73696e6761706f7265227d/allah/freqtrade/json_dict/ccxt.ipynb#W0sdnNjb2RlLXJlbW90ZQ%3D%3D?line=113'>114</a> api_secret = testnet_api_secret
# --> <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a224c696e6f64655f73696e6761706f7265227d/allah/freqtrade/json_dict/ccxt.ipynb#W0sdnNjb2RlLXJlbW90ZQ%3D%3D?line=115'>116</a> asyncio.run(main())
#
# File /allah/freqtrade/.venv/lib/python3.11/site-packages/nest_asyncio.py:31, in _patch_asyncio.<locals>.run(main, debug)
#      29 task = asyncio.ensure_future(main)
#      30 try:
# ---> 31     return loop.run_until_complete(task)
#      32 finally:
#      33     if not task.done():
#
# File /allah/freqtrade/.venv/lib/python3.11/site-packages/nest_asyncio.py:99, in _patch_loop.<locals>.run_until_complete(self, future)
#      96 if not f.done():
#      97     raise RuntimeError(
#      98         'Event loop stopped before Future completed.')
# ---> 99 return f.result()
#
# File /usr/lib/python3.11/asyncio/futures.py:203, in Future.result(self)
#     201 self.__log_traceback = False
#     202 if self._exception is not None:
# --> 203     raise self._exception.with_traceback(self._exception_tb)
#     204 return self._result
#
# File /usr/lib/python3.11/asyncio/tasks.py:269, in Task.__step(***failed resolving arguments***)
#     267         result = coro.send(None)
#     268     else:
# --> 269         result = coro.throw(exc)
#     270 except StopIteration as exc:
#     271     if self._must_cancel:
#     272         # Task is cancelled right before coro stops.
#
# /allah/freqtrade/json_dict/ccxt.ipynb Cell 1 line 1
#     <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a224c696e6f64655f73696e6761706f7265227d/allah/freqtrade/json_dict/ccxt.ipynb#W0sdnNjb2RlLXJlbW90ZQ%3D%3D?line=105'>106</a> exchange.set_sandbox_mode(True)
#     <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a224c696e6f64655f73696e6761706f7265227d/allah/freqtrade/json_dict/ccxt.ipynb#W0sdnNjb2RlLXJlbW90ZQ%3D%3D?line=106'>107</a> tasks = [
#     <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a224c696e6f64655f73696e6761706f7265227d/allah/freqtrade/json_dict/ccxt.ipynb#W0sdnNjb2RlLXJlbW90ZQ%3D%3D?line=107'>108</a>     watch_ohlcv_and_print(exchange, trading_symbol, whale_1),
#     <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a224c696e6f64655f73696e6761706f7265227d/allah/freqtrade/json_dict/ccxt.ipynb#W0sdnNjb2RlLXJlbW90ZQ%3D%3D?line=108'>109</a>     constantly_watch_position_and_orders(exchange, trading_symbol, whale_1)
#     <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a224c696e6f64655f73696e6761706f7265227d/allah/freqtrade/json_dict/ccxt.ipynb#W0sdnNjb2RlLXJlbW90ZQ%3D%3D?line=109'>110</a> ]
# --> <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a224c696e6f64655f73696e6761706f7265227d/allah/freqtrade/json_dict/ccxt.ipynb#W0sdnNjb2RlLXJlbW90ZQ%3D%3D?line=110'>111</a> await asyncio.gather(*tasks)
#
# File /usr/lib/python3.11/asyncio/tasks.py:339, in Task.__wakeup(self, future)
#     337 def __wakeup(self, future):
#     338     try:
# --> 339         future.result()
#     340     except BaseException as exc:
#     341         # This may also be a cancellation.
#     342         self.__step(exc)
#
# File /usr/lib/python3.11/asyncio/tasks.py:269, in Task.__step(***failed resolving arguments***)
#     267         result = coro.send(None)
#     268     else:
# --> 269         result = coro.throw(exc)
#     270 except StopIteration as exc:
#     271     if self._must_cancel:
#     272         # Task is cancelled right before coro stops.
#
# /allah/freqtrade/json_dict/ccxt.ipynb Cell 1 line 3
#      <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a224c696e6f64655f73696e6761706f7265227d/allah/freqtrade/json_dict/ccxt.ipynb#W0sdnNjb2RlLXJlbW90ZQ%3D%3D?line=35'>36</a> try:
#      <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a224c696e6f64655f73696e6761706f7265227d/allah/freqtrade/json_dict/ccxt.ipynb#W0sdnNjb2RlLXJlbW90ZQ%3D%3D?line=36'>37</a>     while True:
# ---> <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a224c696e6f64655f73696e6761706f7265227d/allah/freqtrade/json_dict/ccxt.ipynb#W0sdnNjb2RlLXJlbW90ZQ%3D%3D?line=37'>38</a>         ohlcv = await exchange.watch_ohlcv(symbol, timeframe='1m')
#      <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a224c696e6f64655f73696e6761706f7265227d/allah/freqtrade/json_dict/ccxt.ipynb#W0sdnNjb2RlLXJlbW90ZQ%3D%3D?line=38'>39</a>         timestamp_utc = datetime.fromtimestamp(ohlcv[-1][0] / 1000, tz=pytz.utc)
#      <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a224c696e6f64655f73696e6761706f7265227d/allah/freqtrade/json_dict/ccxt.ipynb#W0sdnNjb2RlLXJlbW90ZQ%3D%3D?line=39'>40</a>         timestamp_utc8 = timestamp_utc.astimezone(utc_plus_8)
#
# File /allah/freqtrade/.venv/lib/python3.11/site-packages/ccxt/pro/binance.py:742, in binance.watch_ohlcv(self, symbol, timeframe, since, limit, params)
#     732 request = {
#     733     'method': 'SUBSCRIBE',
#     734     'params': [
#    (...)
#     737     'id': requestId,
#     738 }
#     739 subscribe = {
#     740     'id': requestId,
#     741 }
# --> 742 ohlcv = await self.watch(url, messageHash, self.extend(request, params), messageHash, subscribe)
#     743 if self.newUpdates:
#     744     limit = ohlcv.getLimit(symbol, limit)
#
# File /usr/lib/python3.11/asyncio/tasks.py:339, in Task.__wakeup(self, future)
#     337 def __wakeup(self, future):
#     338     try:
# --> 339         future.result()
#     340     except BaseException as exc:
#     341         # This may also be a cancellation.
#     342         self.__step(exc)
#
# NetworkError: 1006

# %%
pwd
# Out:
# '/allah/freqtrade/json_dict'
